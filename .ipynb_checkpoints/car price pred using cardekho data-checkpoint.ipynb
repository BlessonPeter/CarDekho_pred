# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install seaborn
# Out:
# ...
#      ---------------------------------------- 0.0/162.8 kB ? eta -:--:--
#      -------------- ------------------------ 61.4/162.8 kB 1.7 MB/s eta 0:00:01
#      ----------------------------------- -- 153.6/162.8 kB 1.8 MB/s eta 0:00:01
#      -------------------------------------- 162.8/162.8 kB 1.4 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/294.9 kB ? eta -:--:--
#    ----------------------- ---------------- 174.1/294.9 kB 5.3 MB/s eta 0:00:01
#    ---------------------------------------- 294.9/294.9 kB 3.6 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/7.7 MB ? eta -:--:--
#    - -------------------------------------- 0.3/7.7 MB 5.4 MB/s eta 0:00:02
#    -- ------------------------------------- 0.5/7.7 MB 5.3 MB/s eta 0:00:02
#    ---- ----------------------------------- 0.8/7.7 MB 4.9 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.0/7.7 MB 5.4 MB/s eta 0:00:02
# ...

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
cardf=pd.read_csv("car data.csv")

# %%
cardf.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %% [markdown]
# #In the dataset Fuel_Type	Seller_Type	Transmission are categorical datas,and coulmn Car_name is not a imp data to  predict the price so we are droping it

# %%
cardf=cardf.drop(columns='Car_Name',axis=1)

# %%
cardf.head()
# Out:
#    Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0  2014           3.35           5.59       27000    Petrol      Dealer
# 1  2013           4.75           9.54       43000    Diesel      Dealer
# 2  2017           7.25           9.85        6900    Petrol      Dealer
# 3  2011           2.85           4.15        5200    Petrol      Dealer
# 4  2014           4.60           6.87       42450    Diesel      Dealer
#
#   Transmission  Owner
# 0       Manual      0
# 1       Manual      0
# 2       Manual      0
# 3       Manual      0
# 4       Manual      0

# %% [markdown]
# we adding a column current year in order to get the amount of year the car manufatured till now by substracting from the year coulmn with current_year

# %%
cardf['current_year']=2024

# %%
cardf.head()
# Out:
#    Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0  2014           3.35           5.59       27000    Petrol      Dealer
# 1  2013           4.75           9.54       43000    Diesel      Dealer
# 2  2017           7.25           9.85        6900    Petrol      Dealer
# 3  2011           2.85           4.15        5200    Petrol      Dealer
# 4  2014           4.60           6.87       42450    Diesel      Dealer
#
#   Transmission  Owner  current_year
# 0       Manual      0          2024
# 1       Manual      0          2024
# 2       Manual      0          2024
# 3       Manual      0          2024
# 4       Manual      0          2024

# %%
cardf['total year']=cardf['current_year']-cardf['Year']

# %%
cardf.head()
# Out:
#    Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0  2014           3.35           5.59       27000    Petrol      Dealer
# 1  2013           4.75           9.54       43000    Diesel      Dealer
# 2  2017           7.25           9.85        6900    Petrol      Dealer
# 3  2011           2.85           4.15        5200    Petrol      Dealer
# 4  2014           4.60           6.87       42450    Diesel      Dealer
#
#   Transmission  Owner  current_year  total year
# 0       Manual      0          2024          10
# 1       Manual      0          2024          11
# 2       Manual      0          2024           7
# 3       Manual      0          2024          13
# 4       Manual      0          2024          10

# %%
#droping year and current year becuase they are not relavant anymore because we already have the total year count ,a derived new feature
cardf.drop(columns=['Year','current_year'],axis=1)
# Out:
#      Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0             3.35           5.59       27000    Petrol      Dealer
# 1             4.75           9.54       43000    Diesel      Dealer
# 2             7.25           9.85        6900    Petrol      Dealer
# 3             2.85           4.15        5200    Petrol      Dealer
# 4             4.60           6.87       42450    Diesel      Dealer
# ..             ...            ...         ...       ...         ...
# 296           9.50          11.60       33988    Diesel      Dealer
# 297           4.00           5.90       60000    Petrol      Dealer
# 298           3.35          11.00       87934    Petrol      Dealer
# 299          11.50          12.50        9000    Diesel      Dealer
# 300           5.30           5.90        5464    Petrol      Dealer
#
#     Transmission  Owner  total year
# 0         Manual      0          10
# 1         Manual      0          11
# 2         Manual      0           7
# ...

# %%
(cardf['Fuel_Type'].value_counts()).plot(kind='bar')
# Out:
# <Axes: xlabel='Fuel_Type'>

# %%
print(cardf['Fuel_Type'].unique())
print(cardf['Seller_Type'].unique())
print(cardf['Transmission'].unique())
# Out:
# ['Petrol' 'Diesel' 'CNG']
# ['Dealer' 'Individual']
# ['Manual' 'Automatic']
